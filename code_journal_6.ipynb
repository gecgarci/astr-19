# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # sin functions find the unknown angle or sides of a right triangle
# # cos functions solves problems involving distance or height, or if you need to know an angle measure

# %%
def sin():
    print(sin(x))
def cos():
    print(cos(x))

# %%
x=np.linspace(0,3*np.pi,1000)
plt.ylim(-1.2,1.2)
plt.xlim(0,2*np.pi)
plt.plot(x, np.sin(x))
plt.xlabel('x')
plt.ylabel('sin(x)')
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
x=np.linspace(0,3*np.pi,1000)
plt.ylim(-1.2,1.2)
plt.xlim(0,2*np.pi)
plt.plot(x, np.cos(x))
plt.xlabel('x')
plt.ylabel('cos(x)')
# Out:
# Text(0, 0.5, 'cos(x)')

# %%
for ii in range(10):
    print(x[ii], np.sin(x)[0], np.cos(x)[0])
x[ii], sinx[0], cosx[0]
# Out:
# 0.0 0.0 1.0
# 0.009434212172942321 0.0 1.0
# 0.018868424345884642 0.0 1.0
# 0.028302636518826963 0.0 1.0
# 0.037736848691769284 0.0 1.0
# 0.04717106086471161 0.0 1.0
# 0.056605273037653926 0.0 1.0
# 0.06603948521059624 0.0 1.0
# 0.07547369738353857 0.0 1.0
# 0.08490790955648089 0.0 1.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 for ii in range(10):
#       2     print(x[ii], np.sin(x)[0], np.cos(x)[0])
# ----> 3 x[ii], sinx[0], cosx[0]
#
# NameError: name 'sinx' is not defined
