# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,3*np.pi,1000)
plt.ylim(-1.2,1.2)
plt.xlim(0,2*np.pi)
plt.plot(x, np.sin(x))
plt.xlabel('x')
plt.ylabel('sin(x)')
# Out:
# Text(0, 0.5, 'sin(x)')
